# %% [markdown]
# <style>
# h1, h1 *,
# h2, h2 *,
# h3, h3 *,
# h4, h4 *,
# h5, h5 *,
# h6, h6 * {
#   font-family: "Times New Roman", Times, serif !important;
#
# </style>
#
# ### **Hotel Booking Cancellations Prediction**

# %% [markdown]
# ---
